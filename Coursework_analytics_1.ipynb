# %% [markdown]
# # Курсовая работа. Блок 1
# *Pandas и Matplotlib*
#
# **NB!** Код должен быть с комментариями к каждому логическому блоку кода. В противном случае работа **не** будет принята. <br><br>
# Выполнение курсовой работы может потребовать использование дополнительных библиотек.
#
# <br><br>
# **Описание работы:**
#
# Перед вами стоит бизнес-задача – на основании имеющихся данных подготовить аналитический отчет, который в дальнейшем поможет продюсерам образовательных программ эффективно выстраивать стратегию по модернизированию и улучшению курсов. В начале отчета предлагается оформить емкий описательный блок по каждому курсу на основании рассчитанных показателей. Далее предлагается посчитать потенциальную нагрузку на преподавателей, чтобы оценить необходимость расширения штата сотрудников. Затем идет блок из двух пунктов по анализу качества контента курсов, где необходимо выявить проблемные модули, которые, возможно, требуют доработки. Также стоит задача выявить потенциальную сезонность. Наконец, предложено задание для самостоятельной разработки метрики успеваемости студентов для нахождения тех, кто значительно хуже справляются с прохождением курса. Каждый из пунктов анализа предполагается сопроводить аналитическим выводом на основании рассчитанных метрик.
#
# <br><br>
#
# _________
# Обозначения:<br><br>
# &nbsp;&nbsp;&nbsp;&nbsp;**(p)** – задание может быть выполнено после прохождения модулей по Pandas <br>
# &nbsp;&nbsp;&nbsp;&nbsp;**(m)** – задание может быть выполнено после прохождения модуля по Matplotlib <br>
# &nbsp;&nbsp;&nbsp;&nbsp;⭐ – необязательное задание повышенной сложности
# _________
#
# [Codebook](#Codebook) <br>
# [1. Описание и начальная работа с данными](#1.1-Описание-и-начальная-работа-с-данными)<br>
# [2. Расчет потенциальной нагрузки на преподавателей](#2.-Расчет-потенциальной-нагрузки-на-преподавателей)<br>
# [3. Выявление проблемных модулей](#3.-Выявление-проблемных-модулей)<br>
# [4. Расчет конверсии](#4.-Расчет-конверсии) <br>
# [5. Метрика успеваемости ](#5.-Метрика-успеваемости)

# %% [markdown]
# ## Codebook
#
# `courses.csv` содержит следующие значения: <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp; `id` – идентификатор курса <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `title` – название курса <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `field` – сфера, к которой относится курс <br> <br><br>
# `students.csv` содержит следующие значения: <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp; `id` – идентификатор студента <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `city` – город студента <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `birthday` – день рождения студента <br> <br><br>
# `course_contents.csv` содержит следующие значения: <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp; `course_id` – идентификатор курса <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `module_number` – номер модуля <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `module_title` – название модуля <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `lesson_number` – номер урока <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `lesson_title` – название урока <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `lesson_token` – токен урока <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `is_video` – наличие видео *(true/false)* <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `is_homework` – наличие домашней работы *(true/false)* <br>
# <br><br>
# `progresses.csv` содержит следующие значения: <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp; `id` – идентификатор прогресса <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `student_id` – идентификатор студента <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `course_id` – идентификатор курса <br> <br><br>
# `progress_phases.csv` содержит следующие значения: <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp; `progress_id` – идентификатор прогресса <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `module_number` – номер модуля <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `lesson_number` – номер урока <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `status` – статус прохождения урока <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `start_date` – дата начала <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `finish_date` – дата окончания <br>
# <br><br>

# %% [markdown]
# ## 1. Описание и начальная работа с данными
#
# Вам необходимо подготовить данные и описать их. Данные реальные и содержат пропущенные значения, а также лишние относительно друг друга данные. <br>
#
# Объедините датасеты (кроме `students.scv`) в один общий для дальнейшей работы. Отдельный датасет создайте для расчета среднего возраста студентов курсов (отдельный датасет со `students.scv` нужен, чтобы в основном не потерять значения в основном датасете из-за того, что не по всем студентам есть анкетные данные о дате рождения). <br> <br>
# Опишите данные: <br>
# 1. **(p)** Посчитайте
#       * общее количество курсов в датасете,
#       * количество модулей на каждом курсе,
#       * количество уроков в каждом модуле на каждом курсе,
#       * медианное количество уроков в модуле на каждом курсе,
#       * количество учеников на каждом курсе
#       * минимальный, максимальный, средний, медианный возраст студентов
#       * минимальный, максимальный, средний, медианный возраст студентов на каждом курсе
# 2. **(m)** Постройте bar-chart, отражающий количество студентов на каждом курсе. Ticks нужно развернуть так, чтобы они были читаемы
# 3. **(m)** Постройте горизонтальный (столбцы должны располагаться горизонтально) bar-chart, отражающий количество студентов на каждом курсе. График должен иметь заголовок. Значения должны быть отсортированы. Цвет столбцов должен содержать информацию о сфере, к которой относится курс (то есть нужна легенда). Прозрачность должна стоять на отметке 0.1. На график должна быть нанесена линия медианы. У медианы должен быть свой цвет. Рамки у графика быть не должно ⭐
# 4.     На основании рассчитанных значений опишите данные (описание должно быть полным и покрывать все полученные выше метрики)
#
# _____________________________________________________________________

# %% [markdown]
# Для того, чтобы проверить, что вы правильно соединили все датасеты в основной (без `students.csv`), запустите аналогичный приведенному ниже запрос. Выдача должна совпадать. Имейте в виду, что названия некоторых столбцов были переименованы.

# %%
# main[main.student_id == '768c2987a744c51ce64a5993a2a94eaf'] # проверка основного датасета

# %%
### YOUR CODE HERE ###

import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
# %matplotlib inline

course_contents_df = pd.read_csv('./data/course_contents.csv')
courses_df = pd.read_csv('./data/courses.csv')
progresses_df = pd.read_csv('./data/progresses.csv')
progress_phases_df = pd.read_csv('./data/progress_phases.csv')
students_df = pd.read_csv('./data/students.csv')
students_ages_dfd = students_df.copy(deep=True)

# %%
courses_merged_df = courses_df.merge(course_contents_df, left_on='id', right_on='course_id')
progresses_merged_df = progresses_df.merge(progress_phases_df, left_on='id', right_on='progress_id')
main = courses_merged_df.merge(progresses_merged_df, on=['module_number','lesson_number', 'course_id'])

# %%
main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 350677 entries, 0 to 350676
# Data columns (total 18 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Unnamed: 0     350677 non-null  int64
#  1   id_x           350677 non-null  object
#  2   title          350677 non-null  object
#  3   field          350677 non-null  object
#  4   course_id      350677 non-null  object
#  5   module_number  350677 non-null  int64
#  6   module_title   350677 non-null  object
#  7   lesson_number  350677 non-null  int64
#  8   lesson_title   350677 non-null  object
#  9   lesson_token   350677 non-null  object
#  10  is_video       350677 non-null  bool
#  11  is_homework    350677 non-null  bool
#  12  id_y           350677 non-null  object
#  13  student_id     350677 non-null  object
#  14  progress_id    350677 non-null  object
#  15  status         350677 non-null  object
#  16  start_date     350677 non-null  object
#  17  finish_date    334508 non-null  object
# dtypes: bool(2), int64(3), object(13)
# memory usage: 46.2+ MB

# %%
# общее количество курсов в датасете, 
main.groupby('course_id').count().shape[0]
# Out:
# 15

# %%
main['course_id'].value_counts().count()
# Out:
# 15

# %%
main['course_id'].nunique()
# Out:
# 15

# %%
# количество модулей на каждом курсе

main.groupby(['course_id','title','module_number']).count().groupby(['course_id','title'])['Unnamed: 0'].count()
# Out:
# course_id                         title
# 04ba6d0b40670c43a209141fa01fa784  Анимация интерфейсов                   21
# 0770b1b039964228294f1f34b29fc2c1  Руководитель digital-проектов          17
# 17013cd19d25cb3f28dc1b2683721bb9  Веб-дизайн Базовый                     17
# 480d25ad36878fce09e7aada316ba1a6  Веб-разработчик                        20
# 6e4837f0a65c68efbfdd0594d6774701  Java-разработчик                       17
# 842218e7c983795934bbe4533c0888c8  SMM-маркетолог от А до Я               11
# 943306102e5b067d08a29094f37b8193  Java-разработчик c нуля                 9
# abce125a877c2196a3bc7bfbc11b5fc5  Веб-вёрстка для начинающих 2.0          8
# ac634845fb0350d0e9d49078aaa4b68f  Excel Базовый                           9
# bf27a4bf4ada4c756451703ea62a914f  Интернет-маркетолог от Ingate          18
# c9fcb746d51e41bc5a217002d081454b  Веб-дизайн PRO 2.0                     17
# ccbab00e99b27f83369d6cc89d914ad6  PHP-разработчик с 0 до PRO. Часть 1     8
# dad6f6ffc086caa89e2f40c28a9c7490  UX-дизайн                              20
# e3a0df907589d56692b5cb561fd90d87  Веб-дизайн с нуля 2.0                  19
# e9bb9205eeed307ee7cbaa08bfd166c3  JavaScript с нуля                      18
# Name: Unnamed: 0, dtype: int64

# %%
main.pivot_table('Unnamed: 0',index=['course_id','title','module_number']).groupby(['course_id','title']).count().head(20)
# Out:
#                                                                       Unnamed: 0
# course_id                        title
# 04ba6d0b40670c43a209141fa01fa784 Анимация интерфейсов                         21
# 0770b1b039964228294f1f34b29fc2c1 Руководитель digital-проектов                17
# 17013cd19d25cb3f28dc1b2683721bb9 Веб-дизайн Базовый                           17
# 480d25ad36878fce09e7aada316ba1a6 Веб-разработчик                              20
# 6e4837f0a65c68efbfdd0594d6774701 Java-разработчик                             17
# 842218e7c983795934bbe4533c0888c8 SMM-маркетолог от А до Я                     11
# 943306102e5b067d08a29094f37b8193 Java-разработчик c нуля                       9
# abce125a877c2196a3bc7bfbc11b5fc5 Веб-вёрстка для начинающих 2.0                8
# ac634845fb0350d0e9d49078aaa4b68f Excel Базовый                                 9
# bf27a4bf4ada4c756451703ea62a914f Интернет-маркетолог от Ingate                18
# c9fcb746d51e41bc5a217002d081454b Веб-дизайн PRO 2.0                           17
# ccbab00e99b27f83369d6cc89d914ad6 PHP-разработчик с 0 до PRO. Часть 1           8
# dad6f6ffc086caa89e2f40c28a9c7490 UX-дизайн                                    20
# e3a0df907589d56692b5cb561fd90d87 Веб-дизайн с нуля 2.0                        19
# e9bb9205eeed307ee7cbaa08bfd166c3 JavaScript с нуля                            18

# %%
# количество уроков в каждом модуле на каждом курсе

main.groupby(['course_id','title','module_number','module_title',
              'lesson_number']).count().reset_index().groupby(['course_id','title','module_number',
                                                               'module_title']).aggregate({'lesson_number':'count'})
# Out:
#                                                                                                                         lesson_number
# course_id                        title                module_number module_title
# 04ba6d0b40670c43a209141fa01fa784 Анимация интерфейсов 1             Введение в Motion Design. Тренды, разновидности...              3
#                                                       2             12 принципов анимации от Walt Disney Studio                     3
#                                                       3             Motion design в интерфейсах                                     4
#                                                       4             After Effects                                                   4
#                                                       5             Иконки — погружение в мир микроанимации                         4
# ...                                                                                                                               ...
# e9bb9205eeed307ee7cbaa08bfd166c3 JavaScript с нуля    14            Сборка проектов                                                 6
#                                                       15            React                                                           6
#                                                       16            Redux                                                           7
#                                                       17            Бонус                                                           3
#                                                       18            Экзаменационное задание                                         1
#
# [229 rows x 1 columns]

# %%
main.pivot_table(values='lesson_number',
                                         index=['course_id','title','module_number','module_title'],
                                         aggfunc='nunique').iloc[:,1:2].head(20)
# Out:
#                                                                                                                         lesson_number
# course_id                        title                module_number module_title
# 04ba6d0b40670c43a209141fa01fa784 Анимация интерфейсов 1             Введение в Motion Design. Тренды, разновидности...              3
#                                                       2             12 принципов анимации от Walt Disney Studio                     3
#                                                       3             Motion design в интерфейсах                                     4
#                                                       4             After Effects                                                   4
#                                                       5             Иконки — погружение в мир микроанимации                         4
#                                                       6             Бонус-модуль. Экспорт анимации в код. Плагин Bo...              1
#                                                       7             Прелоадеры                                                      3
#                                                       8             Material Design                                                 3
#                                                       9             Бонус-модуль. Звуки в интерфейсе                                1
#                                                       10            Principle (обновлён 06.06.19)                                   7
#                                                       11            Webflow — инструмент прототипирования веб-интер...              3
#                                                       12            InVision Studio                                                 6
#                                                       13            Анимация статичной концепции                                    5
#                                                       14            Видеобаннеры. Тренд, который заслуживает внимания               4
#                                                       15            Анимация концепции для презентации клиенту                      4
#                                                       16            Бонус-модуль. Анимация в верстке                                1
#                                                       17            Бонус-модуль. Практика: разбор кейса Уралсиб                    1
#                                                       18            Чистая магия — cоздание продающего шоурила                      3
#                                                       19            Рабочие будни моушн-дизайнера                                   1
#                                                       20            Дьявол в деталях                                                1

# %%
temp_df = main.pivot_table(values='lesson_number',
                                         index=['course_id','title','module_number','module_title'],
                                         aggfunc='nunique')['lesson_number']

# %%
# количество уроков на каждом курсе

# %%
temp_df.reset_index().groupby(['course_id','title']).agg({'lesson_number':'sum'})
# Out:
#                                                                       lesson_number
# course_id                        title
# 04ba6d0b40670c43a209141fa01fa784 Анимация интерфейсов                            63
# 0770b1b039964228294f1f34b29fc2c1 Руководитель digital-проектов                   96
# 17013cd19d25cb3f28dc1b2683721bb9 Веб-дизайн Базовый                              59
# 480d25ad36878fce09e7aada316ba1a6 Веб-разработчик                                 35
# 6e4837f0a65c68efbfdd0594d6774701 Java-разработчик                               114
# 842218e7c983795934bbe4533c0888c8 SMM-маркетолог от А до Я                        62
# 943306102e5b067d08a29094f37b8193 Java-разработчик c нуля                        115
# abce125a877c2196a3bc7bfbc11b5fc5 Веб-вёрстка для начинающих 2.0                  55
# ac634845fb0350d0e9d49078aaa4b68f Excel Базовый                                   49
# bf27a4bf4ada4c756451703ea62a914f Интернет-маркетолог от Ingate                  171
# c9fcb746d51e41bc5a217002d081454b Веб-дизайн PRO 2.0                              66
# ccbab00e99b27f83369d6cc89d914ad6 PHP-разработчик с 0 до PRO. Часть 1             41
# dad6f6ffc086caa89e2f40c28a9c7490 UX-дизайн                                       73
# e3a0df907589d56692b5cb561fd90d87 Веб-дизайн с нуля 2.0                           82
# e9bb9205eeed307ee7cbaa08bfd166c3 JavaScript с нуля                              119

# %%
# медианное количество уроков в модуле на каждом курсе

temp_df.reset_index().groupby(['course_id','title']).agg({'lesson_number':'median'})
# Out:
#                                                                       lesson_number
# course_id                        title
# 04ba6d0b40670c43a209141fa01fa784 Анимация интерфейсов                           3.0
# 0770b1b039964228294f1f34b29fc2c1 Руководитель digital-проектов                  5.0
# 17013cd19d25cb3f28dc1b2683721bb9 Веб-дизайн Базовый                             3.0
# 480d25ad36878fce09e7aada316ba1a6 Веб-разработчик                                2.0
# 6e4837f0a65c68efbfdd0594d6774701 Java-разработчик                               7.0
# 842218e7c983795934bbe4533c0888c8 SMM-маркетолог от А до Я                       6.0
# 943306102e5b067d08a29094f37b8193 Java-разработчик c нуля                       13.0
# abce125a877c2196a3bc7bfbc11b5fc5 Веб-вёрстка для начинающих 2.0                 7.0
# ac634845fb0350d0e9d49078aaa4b68f Excel Базовый                                  5.0
# bf27a4bf4ada4c756451703ea62a914f Интернет-маркетолог от Ingate                  6.5
# c9fcb746d51e41bc5a217002d081454b Веб-дизайн PRO 2.0                             5.0
# ccbab00e99b27f83369d6cc89d914ad6 PHP-разработчик с 0 до PRO. Часть 1            4.0
# dad6f6ffc086caa89e2f40c28a9c7490 UX-дизайн                                      3.5
# e3a0df907589d56692b5cb561fd90d87 Веб-дизайн с нуля 2.0                          4.0
# e9bb9205eeed307ee7cbaa08bfd166c3 JavaScript с нуля                              7.0

# %%
# минимальный, максимальный, средний, медианный возраст студентов

# %%
students_temp_df = students_df #[students_df.birthday.isna()==False]

# %%
students_temp_df['today_date'] = datetime.today().strftime("%Y-%m-%d")

# %%
students_temp_df['age'] = (pd.to_datetime(temp_df['today_date'],errors='coerce',format="%Y-%m-%d") \
                                   - pd.to_datetime(temp_df['birthday'],errors='coerce',format="%Y-%m-%d")).astype('<m8[Y]')

# %%
students_temp_df.agg({'age': ['max', 'mean', 'median']})
# Out:
#                age
# max     135.000000
# mean     28.905924
# median   28.000000

# %%
students_temp_df = students_temp_df.drop(['today_date'], axis=1)

# %%
students_temp_df
# Out:
#           id_                                id              city    birthday  \
# 0        1325  35e8a1938b9a33d5e45c8f4451c4309a               NaN         NaN
# 1        7503  6c3e52be632fc50de9640147e4017dcd            Москва  1979-10-23
# 2        8972  2033122d7c9b24b36eebc468d5259642               NaN         NaN
# 3        9235  a6ae278c0eab719b3784e5ea147c128f            Москва         NaN
# 4        9588  51b25c9afd20d178ef3c07276df38e2d  Великий Новгород         NaN
# ...       ...                               ...               ...         ...
# 43825  124251  a65ccacbe0226b345f195d02e676aa04               NaN  2000-11-21
# 43826  124338  148f1375e4135e779053a0d4b2a63857               NaN  1999-10-20
# 43827  124363  05fa419f832fa78ad6e7a5f90b0f71e6               NaN         NaN
# 43828  124377  9ff58c490f6ee5b013e7f62140ee3d79               NaN  1998-04-18
# 43829  124445  5c02b021cef9b775bb874bf1658ffb58               NaN         NaN
#
#         age
# 0       NaN
# 1      40.0
# 2       NaN
# 3       NaN
# 4       NaN
# ...     ...
# 43825  19.0
# 43826  20.0
# 43827   NaN
# 43828  21.0
# 43829   NaN
#
# [43830 rows x 5 columns]

# %%
# минимальный, максимальный, средний, медианный возраст студентов на каждом курсе

# %%
courses_df.head()
# Out:
#    Unnamed: 0                                id  \
# 0           0  943306102e5b067d08a29094f37b8193
# 1           1  17013cd19d25cb3f28dc1b2683721bb9
# 2           2  ac634845fb0350d0e9d49078aaa4b68f
# 3           3  0770b1b039964228294f1f34b29fc2c1
# 4           4  abce125a877c2196a3bc7bfbc11b5fc5
#
#                             title        field
# 0         Java-разработчик c нуля  Development
# 1              Веб-дизайн Базовый       Design
# 2                   Excel Базовый     Business
# 3   Руководитель digital-проектов     Business
# 4  Веб-вёрстка для начинающих 2.0  Development

# %%
courses_progresses_merged_df = courses_df.merge(progresses_df, left_on='id', right_on='course_id')

# %%
temp_df = courses_progresses_merged_df.merge(students_temp_df, left_on='student_id', right_on='id')

# %%
temp_df.groupby(['course_id','title']).aggregate({'age':['min','max','mean','median']})
# Out:
#                                                                         age  \
#                                                                         min
# course_id                        title
# 04ba6d0b40670c43a209141fa01fa784 Анимация интерфейсов                 -15.0
# 0770b1b039964228294f1f34b29fc2c1 Руководитель digital-проектов          1.0
# 17013cd19d25cb3f28dc1b2683721bb9 Веб-дизайн Базовый                    15.0
# 480d25ad36878fce09e7aada316ba1a6 Веб-разработчик                       13.0
# 6e4837f0a65c68efbfdd0594d6774701 Java-разработчик                       5.0
# 842218e7c983795934bbe4533c0888c8 SMM-маркетолог от А до Я               1.0
# 943306102e5b067d08a29094f37b8193 Java-разработчик c нуля                5.0
# abce125a877c2196a3bc7bfbc11b5fc5 Веб-вёрстка для начинающих 2.0       -56.0
# ac634845fb0350d0e9d49078aaa4b68f Excel Базовый                          1.0
# bf27a4bf4ada4c756451703ea62a914f Интернет-маркетолог от Ingate          1.0
# c9fcb746d51e41bc5a217002d081454b Веб-дизайн PRO 2.0                  -161.0
# ccbab00e99b27f83369d6cc89d914ad6 PHP-разработчик с 0 до PRO. Часть 1    1.0
# dad6f6ffc086caa89e2f40c28a9c7490 UX-дизайн                              1.0
# e3a0df907589d56692b5cb561fd90d87 Веб-дизайн с нуля 2.0                -56.0
# e9bb9205eeed307ee7cbaa08bfd166c3 JavaScript с нуля                    -56.0
#
#                                                                              \
#                                                                         max
# course_id                        title
# 04ba6d0b40670c43a209141fa01fa784 Анимация интерфейсов                  51.0
# 0770b1b039964228294f1f34b29fc2c1 Руководитель digital-проектов         54.0
# 17013cd19d25cb3f28dc1b2683721bb9 Веб-дизайн Базовый                    51.0
# 480d25ad36878fce09e7aada316ba1a6 Веб-разработчик                       50.0
# 6e4837f0a65c68efbfdd0594d6774701 Java-разработчик                      64.0
# 842218e7c983795934bbe4533c0888c8 SMM-маркетолог от А до Я              51.0
# 943306102e5b067d08a29094f37b8193 Java-разработчик c нуля               54.0
# abce125a877c2196a3bc7bfbc11b5fc5 Веб-вёрстка для начинающих 2.0        59.0
# ac634845fb0350d0e9d49078aaa4b68f Excel Базовый                         60.0
# bf27a4bf4ada4c756451703ea62a914f Интернет-маркетолог от Ingate        100.0
# c9fcb746d51e41bc5a217002d081454b Веб-дизайн PRO 2.0                    59.0
# ccbab00e99b27f83369d6cc89d914ad6 PHP-разработчик с 0 до PRO. Часть 1   74.0
# dad6f6ffc086caa89e2f40c28a9c7490 UX-дизайн                             85.0
# e3a0df907589d56692b5cb561fd90d87 Веб-дизайн с нуля 2.0                119.0
# e9bb9205eeed307ee7cbaa08bfd166c3 JavaScript с нуля                     59.0
#
#                                                                                  \
#                                                                            mean
# course_id                        title
# 04ba6d0b40670c43a209141fa01fa784 Анимация интерфейсов                 29.343228
# 0770b1b039964228294f1f34b29fc2c1 Руководитель digital-проектов        31.198934
# 17013cd19d25cb3f28dc1b2683721bb9 Веб-дизайн Базовый                   28.468085
# 480d25ad36878fce09e7aada316ba1a6 Веб-разработчик                      28.029851
# 6e4837f0a65c68efbfdd0594d6774701 Java-разработчик                     29.161337
# 842218e7c983795934bbe4533c0888c8 SMM-маркетолог от А до Я             28.865462
# 943306102e5b067d08a29094f37b8193 Java-разработчик c нуля              29.359725
# abce125a877c2196a3bc7bfbc11b5fc5 Веб-вёрстка для начинающих 2.0       28.381496
# ac634845fb0350d0e9d49078aaa4b68f Excel Базовый                        33.392216
# bf27a4bf4ada4c756451703ea62a914f Интернет-маркетолог от Ingate        31.102949
# c9fcb746d51e41bc5a217002d081454b Веб-дизайн PRO 2.0                   28.125468
# ccbab00e99b27f83369d6cc89d914ad6 PHP-разработчик с 0 до PRO. Часть 1  29.277228
# dad6f6ffc086caa89e2f40c28a9c7490 UX-дизайн                            29.898305
# e3a0df907589d56692b5cb561fd90d87 Веб-дизайн с нуля 2.0                28.001564
# e9bb9205eeed307ee7cbaa08bfd166c3 JavaScript с нуля                    28.308279
#
#
#                                                                      median
# course_id                        title
# 04ba6d0b40670c43a209141fa01fa784 Анимация интерфейсов                  29.0
# 0770b1b039964228294f1f34b29fc2c1 Руководитель digital-проектов         31.0
# 17013cd19d25cb3f28dc1b2683721bb9 Веб-дизайн Базовый                    28.0
# 480d25ad36878fce09e7aada316ba1a6 Веб-разработчик                       27.0
# 6e4837f0a65c68efbfdd0594d6774701 Java-разработчик                      28.0
# 842218e7c983795934bbe4533c0888c8 SMM-маркетолог от А до Я              28.0
# 943306102e5b067d08a29094f37b8193 Java-разработчик c нуля               29.0
# abce125a877c2196a3bc7bfbc11b5fc5 Веб-вёрстка для начинающих 2.0        28.0
# ac634845fb0350d0e9d49078aaa4b68f Excel Базовый                         34.0
# bf27a4bf4ada4c756451703ea62a914f Интернет-маркетолог от Ingate         30.0
# c9fcb746d51e41bc5a217002d081454b Веб-дизайн PRO 2.0                    27.0
# ccbab00e99b27f83369d6cc89d914ad6 PHP-разработчик с 0 до PRO. Часть 1   28.0
# dad6f6ffc086caa89e2f40c28a9c7490 UX-дизайн                             29.0
# e3a0df907589d56692b5cb561fd90d87 Веб-дизайн с нуля 2.0                 27.0
# e9bb9205eeed307ee7cbaa08bfd166c3 JavaScript с нуля                     28.0

# %%
temp_df[temp_df.age>0].groupby(['course_id','title']).aggregate({'age':['min','max','mean','median']})
# Out:
#                                                                        age  \
#                                                                        min
# course_id                        title
# 04ba6d0b40670c43a209141fa01fa784 Анимация интерфейсов                  1.0
# 0770b1b039964228294f1f34b29fc2c1 Руководитель digital-проектов         1.0
# 17013cd19d25cb3f28dc1b2683721bb9 Веб-дизайн Базовый                   15.0
# 480d25ad36878fce09e7aada316ba1a6 Веб-разработчик                      13.0
# 6e4837f0a65c68efbfdd0594d6774701 Java-разработчик                      5.0
# 842218e7c983795934bbe4533c0888c8 SMM-маркетолог от А до Я              1.0
# 943306102e5b067d08a29094f37b8193 Java-разработчик c нуля               5.0
# abce125a877c2196a3bc7bfbc11b5fc5 Веб-вёрстка для начинающих 2.0        1.0
# ac634845fb0350d0e9d49078aaa4b68f Excel Базовый                         1.0
# bf27a4bf4ada4c756451703ea62a914f Интернет-маркетолог от Ingate         1.0
# c9fcb746d51e41bc5a217002d081454b Веб-дизайн PRO 2.0                    1.0
# ccbab00e99b27f83369d6cc89d914ad6 PHP-разработчик с 0 до PRO. Часть 1   1.0
# dad6f6ffc086caa89e2f40c28a9c7490 UX-дизайн                             1.0
# e3a0df907589d56692b5cb561fd90d87 Веб-дизайн с нуля 2.0                 1.0
# e9bb9205eeed307ee7cbaa08bfd166c3 JavaScript с нуля                     1.0
#
#                                                                              \
#                                                                         max
# course_id                        title
# 04ba6d0b40670c43a209141fa01fa784 Анимация интерфейсов                  51.0
# 0770b1b039964228294f1f34b29fc2c1 Руководитель digital-проектов         54.0
# 17013cd19d25cb3f28dc1b2683721bb9 Веб-дизайн Базовый                    51.0
# 480d25ad36878fce09e7aada316ba1a6 Веб-разработчик                       50.0
# 6e4837f0a65c68efbfdd0594d6774701 Java-разработчик                      64.0
# 842218e7c983795934bbe4533c0888c8 SMM-маркетолог от А до Я              51.0
# 943306102e5b067d08a29094f37b8193 Java-разработчик c нуля               54.0
# abce125a877c2196a3bc7bfbc11b5fc5 Веб-вёрстка для начинающих 2.0        59.0
# ac634845fb0350d0e9d49078aaa4b68f Excel Базовый                         60.0
# bf27a4bf4ada4c756451703ea62a914f Интернет-маркетолог от Ingate        100.0
# c9fcb746d51e41bc5a217002d081454b Веб-дизайн PRO 2.0                    59.0
# ccbab00e99b27f83369d6cc89d914ad6 PHP-разработчик с 0 до PRO. Часть 1   74.0
# dad6f6ffc086caa89e2f40c28a9c7490 UX-дизайн                             85.0
# e3a0df907589d56692b5cb561fd90d87 Веб-дизайн с нуля 2.0                119.0
# e9bb9205eeed307ee7cbaa08bfd166c3 JavaScript с нуля                     59.0
#
#                                                                                  \
#                                                                            mean
# course_id                        title
# 04ba6d0b40670c43a209141fa01fa784 Анимация интерфейсов                 29.425651
# 0770b1b039964228294f1f34b29fc2c1 Руководитель digital-проектов        31.198934
# 17013cd19d25cb3f28dc1b2683721bb9 Веб-дизайн Базовый                   28.468085
# 480d25ad36878fce09e7aada316ba1a6 Веб-разработчик                      28.029851
# 6e4837f0a65c68efbfdd0594d6774701 Java-разработчик                     29.161337
# 842218e7c983795934bbe4533c0888c8 SMM-маркетолог от А до Я             28.865462
# 943306102e5b067d08a29094f37b8193 Java-разработчик c нуля              29.359725
# abce125a877c2196a3bc7bfbc11b5fc5 Веб-вёрстка для начинающих 2.0       28.429714
# ac634845fb0350d0e9d49078aaa4b68f Excel Базовый                        33.392216
# bf27a4bf4ada4c756451703ea62a914f Интернет-маркетолог от Ingate        31.102949
# c9fcb746d51e41bc5a217002d081454b Веб-дизайн PRO 2.0                   28.243598
# ccbab00e99b27f83369d6cc89d914ad6 PHP-разработчик с 0 до PRO. Часть 1  29.277228
# dad6f6ffc086caa89e2f40c28a9c7490 UX-дизайн                            29.898305
# e3a0df907589d56692b5cb561fd90d87 Веб-дизайн с нуля 2.0                28.045383
# e9bb9205eeed307ee7cbaa08bfd166c3 JavaScript с нуля                    28.400218
#
#
#                                                                      median
# course_id                        title
# 04ba6d0b40670c43a209141fa01fa784 Анимация интерфейсов                  29.0
# 0770b1b039964228294f1f34b29fc2c1 Руководитель digital-проектов         31.0
# 17013cd19d25cb3f28dc1b2683721bb9 Веб-дизайн Базовый                    28.0
# 480d25ad36878fce09e7aada316ba1a6 Веб-разработчик                       27.0
# 6e4837f0a65c68efbfdd0594d6774701 Java-разработчик                      28.0
# 842218e7c983795934bbe4533c0888c8 SMM-маркетолог от А до Я              28.0
# 943306102e5b067d08a29094f37b8193 Java-разработчик c нуля               29.0
# abce125a877c2196a3bc7bfbc11b5fc5 Веб-вёрстка для начинающих 2.0        28.0
# ac634845fb0350d0e9d49078aaa4b68f Excel Базовый                         34.0
# bf27a4bf4ada4c756451703ea62a914f Интернет-маркетолог от Ingate         30.0
# c9fcb746d51e41bc5a217002d081454b Веб-дизайн PRO 2.0                    27.0
# ccbab00e99b27f83369d6cc89d914ad6 PHP-разработчик с 0 до PRO. Часть 1   28.0
# dad6f6ffc086caa89e2f40c28a9c7490 UX-дизайн                             29.0
# e3a0df907589d56692b5cb561fd90d87 Веб-дизайн с нуля 2.0                 27.0
# e9bb9205eeed307ee7cbaa08bfd166c3 JavaScript с нуля                     28.0

# %%
temp_df[temp_df.age<0]
# Out:
#        Unnamed: 0                              id_x  \
# 6287            4  abce125a877c2196a3bc7bfbc11b5fc5
# 6288            5  e9bb9205eeed307ee7cbaa08bfd166c3
# 6289           10  e3a0df907589d56692b5cb561fd90d87
# 9755            6  04ba6d0b40670c43a209141fa01fa784
# 10731           7  c9fcb746d51e41bc5a217002d081454b
#
#                                 title        field  \
# 6287   Веб-вёрстка для начинающих 2.0  Development
# 6288                JavaScript с нуля  Development
# 6289            Веб-дизайн с нуля 2.0       Design
# 9755             Анимация интерфейсов       Design
# 10731              Веб-дизайн PRO 2.0       Design
#
#                                    id_y                        student_id  \
# 6287   166cffc6cfcbcb786e873ff9755c1e11  1375ced1c54e81e2a4ba2c999f35ba14
# 6288   db1e6ca4539baf32d81d184b8cbf5266  1375ced1c54e81e2a4ba2c999f35ba14
# 6289   0a2b7d7ba26cd6a9fc5749c85bcda1f1  1375ced1c54e81e2a4ba2c999f35ba14
# 9755   509009b6591a0b294831e55f054a6391  7d96955322b18fd6a2b196411427ebcd
# 10731  d95bda52262b25e060293e277f5f03b0  33c56b74ba8fbff1310d011ac6604980
#
#                               course_id    id_  \
# 6287   abce125a877c2196a3bc7bfbc11b5fc5  43205
# 6288   e9bb9205eeed307ee7cbaa08bfd166c3  43205
# 6289   e3a0df907589d56692b5cb561fd90d87  43205
# 9755   04ba6d0b40670c43a209141fa01fa784  30905
# 10731  c9fcb746d51e41bc5a217002d081454b  96997
#
#                                      id             city    birthday    age
# 6287   1375ced1c54e81e2a4ba2c999f35ba14  Санкт-Петербург  2075-11-05  -56.0
# 6288   1375ced1c54e81e2a4ba2c999f35ba14  Санкт-Петербург  2075-11-05  -56.0
# 6289   1375ced1c54e81e2a4ba2c999f35ba14  Санкт-Петербург  2075-11-05  -56.0
# 9755   7d96955322b18fd6a2b196411427ebcd  Санкт-Петербург  2034-08-04  -15.0
# 10731  33c56b74ba8fbff1310d011ac6604980            hОРОД  2180-09-03 -161.0

# %%
temp_df[(temp_df.age > 0) & (temp_df.age < 8)].shape
# Out:
# (44, 12)

# %% [markdown]
# ## 2. Расчет потенциальной нагрузки на преподавателей
#
# 1. **(p)** Рассчитать прирост студентов на каждом курсе в каждом месяце за всю историю (каждый месяц в диапазоне от марта 2016 до июля 2019 включительно). Считать дату начала прохождения курса студентом по дате начала первой домашней работы.
# 2. **(m)** На основании первого пункта построить line-graph с приростом студентов в каждом месяце для каждого курса. 15 графиков. Графики должны иметь заголовки, оси должны быть подписаны. Ticks нужно развернуть так, чтобы они были читаемы.
# 3. **(m)** На основании первого пункта построить line-graph с несколькими линиями, отражающими прирост студентов в каждом месяце для каждого курса. 15 линий на графике. Ticks нужно развернуть так, чтобы они были читаемы. График должен иметь заголовок. Ось, отражающая прирост, должна быть подписана. Линия для каждого курса должна иметь свой цвет (нужна легенда). Рамок у графика быть не должно ⭐
# 4. **(p)** Рассчитать количество прогрессов по выполнению домашних работ в каждом месяце за всю историю (каждый месяц в диапазоне от марта 2016 до июля 2019 включительно) для каждого курса. Учитывать, что выполнение домашнего задания может перетекать из одного месяца в другой (такие дз надо включать в общее число прогрессов для всех месяцев, которые покрывает срок выполнения этих дз)
# 5. **(m)** Построить line-graph по четвертому пункту. 15 графиков. Графики должны иметь заголовки, оси должны быть подписаны. Ticks нужно развернуть так, чтобы они были читаемы
# 6. **(m)** Построить один line-graph для всех курсов по четвертому пункту. 15 линий на графике. Ticks нужно развернуть так, чтобы они были читаемы. График должен иметь заголовок. Ось, отражающая количество прогрессов, должна быть подписана. Линия для каждого курса должна иметь свой цвет (нужна легенда). Рамок у графика быть не должно ⭐
# 7. На основании рассчитанных значений сделайте аналитический вывод (должен быть полным и покрывать все полученные выше метрики)

# %%
### YOUR CODE HERE ###

# %%
# Рассчитать прирост студентов на каждом курсе в каждом месяце за всю историю (каждый месяц в диапазоне от марта 2016 до июля 2019 включительно).

progresses_courses_merged_df = progresses_merged_df.merge(courses_df, left_on='course_id', right_on='id')
progresses_courses_merged_df['months'] = pd.to_datetime(progresses_courses_merged_df['start_date'], errors='coerce')

# %%
#progresses_courses_merged_df['months'] = progresses_courses_merged_df['start_date'].astype('datetime64')#[0].date()

# %%
progresses_courses_merged_df['months']
# Out:
# 0        2018-02-19 19:21:25.013391+00:00
# 1        2018-02-19 19:21:25.002537+00:00
# 2        2018-02-19 19:21:24.985811+00:00
# 3               2018-02-06 21:47:41+00:00
# 4        2018-03-17 13:50:55.262335+00:00
#                        ...
# 350672   2019-06-27 10:34:44.108349+00:00
# 350673   2019-06-27 12:12:02.378083+00:00
# 350674   2019-06-19 17:14:09.650841+00:00
# 350675   2019-07-04 11:44:35.006528+00:00
# 350676   2019-06-19 17:14:11.850575+00:00
# Name: months, Length: 350677, dtype: datetime64[ns, UTC]

# %%
progresses_courses_merged_df['start_date'].sort_values()
# Out:
# 163975           2016-03-10 07:00:19+00
# 163974           2016-03-15 17:39:14+00
# 163978           2016-03-16 16:52:18+00
# 163972           2016-03-17 10:10:13+00
# 163976           2016-03-18 17:56:32+00
#                       ...
# 57425     2019-07-17 07:57:44.811273+00
# 349517    2019-07-17 08:02:52.826291+00
# 66356     2019-07-17 08:05:32.514548+00
# 335222     2019-07-17 08:05:35.77834+00
# 26058     2019-07-17 08:05:50.606895+00
# Name: start_date, Length: 350677, dtype: object

# %%
# Диапазон дат начала выполнения работ студентами входит в диапазон от марта 2016 до июля 2019 включительно -
# ограничивать столбец start_date нет необходимости.

# %%
temp_df = progresses_courses_merged_df.groupby([pd.Grouper(key='months', freq='m'), 'course_id', 'student_id']).count()
temp_df.groupby(['months', 'course_id'])['Unnamed: 0'].count().unstack()
# Out:
# course_id                  04ba6d0b40670c43a209141fa01fa784  \
# months
# 2016-03-31 00:00:00+00:00                               NaN
# 2016-11-30 00:00:00+00:00                               NaN
# 2017-01-31 00:00:00+00:00                               NaN
# 2017-02-28 00:00:00+00:00                               NaN
# 2017-03-31 00:00:00+00:00                               NaN
# 2017-04-30 00:00:00+00:00                               NaN
# 2017-05-31 00:00:00+00:00                               NaN
# 2017-06-30 00:00:00+00:00                               NaN
# 2017-07-31 00:00:00+00:00                               1.0
# 2017-08-31 00:00:00+00:00                               NaN
# 2017-09-30 00:00:00+00:00                               1.0
# 2017-10-31 00:00:00+00:00                               1.0
# 2017-11-30 00:00:00+00:00                               NaN
# 2017-12-31 00:00:00+00:00                               NaN
# 2018-01-31 00:00:00+00:00                               9.0
# 2018-02-28 00:00:00+00:00                              33.0
# 2018-03-31 00:00:00+00:00                              39.0
# 2018-04-30 00:00:00+00:00                              34.0
# 2018-05-31 00:00:00+00:00                              41.0
# 2018-06-30 00:00:00+00:00                             162.0
# 2018-07-31 00:00:00+00:00                             143.0
# 2018-08-31 00:00:00+00:00                             105.0
# 2018-09-30 00:00:00+00:00                             110.0
# 2018-10-31 00:00:00+00:00                              81.0
# 2018-11-30 00:00:00+00:00                              85.0
# 2018-12-31 00:00:00+00:00                             120.0
# 2019-01-31 00:00:00+00:00                             112.0
# 2019-02-28 00:00:00+00:00                              80.0
# 2019-03-31 00:00:00+00:00                              73.0
# 2019-04-30 00:00:00+00:00                              46.0
# 2019-05-31 00:00:00+00:00                              46.0
# 2019-06-30 00:00:00+00:00                              49.0
# 2019-07-31 00:00:00+00:00                              34.0
#
# course_id                  0770b1b039964228294f1f34b29fc2c1  \
# months
# 2016-03-31 00:00:00+00:00                               NaN
# 2016-11-30 00:00:00+00:00                               NaN
# 2017-01-31 00:00:00+00:00                               NaN
# 2017-02-28 00:00:00+00:00                               NaN
# 2017-03-31 00:00:00+00:00                               NaN
# 2017-04-30 00:00:00+00:00                               NaN
# 2017-05-31 00:00:00+00:00                               1.0
# 2017-06-30 00:00:00+00:00                               1.0
# 2017-07-31 00:00:00+00:00                               1.0
# 2017-08-31 00:00:00+00:00                               1.0
# 2017-09-30 00:00:00+00:00                               3.0
# 2017-10-31 00:00:00+00:00                               3.0
# 2017-11-30 00:00:00+00:00                               2.0
# 2017-12-31 00:00:00+00:00                               2.0
# 2018-01-31 00:00:00+00:00                              34.0
# 2018-02-28 00:00:00+00:00                              90.0
# 2018-03-31 00:00:00+00:00                             109.0
# 2018-04-30 00:00:00+00:00                             102.0
# 2018-05-31 00:00:00+00:00                             102.0
# 2018-06-30 00:00:00+00:00                              98.0
# months
# 2016-03-31 00:00:00+00:00                               NaN
# 2016-11-30 00:00:00+00:00                               NaN
# 2017-01-31 00:00:00+00:00                               NaN
# 2017-02-28 00:00:00+00:00                               NaN
# 2017-03-31 00:00:00+00:00                               NaN
# 2017-04-30 00:00:00+00:00                               NaN
# 2017-05-31 00:00:00+00:00                               NaN
# 2017-06-30 00:00:00+00:00                               NaN
# 2017-07-31 00:00:00+00:00                               NaN
# 2017-08-31 00:00:00+00:00                               NaN
# 2017-09-30 00:00:00+00:00                               NaN
# 2017-10-31 00:00:00+00:00                               NaN
# 2017-11-30 00:00:00+00:00                               NaN
# 2017-12-31 00:00:00+00:00                               NaN
# 2018-01-31 00:00:00+00:00                               NaN
# 2018-02-28 00:00:00+00:00                               NaN
# 2018-03-31 00:00:00+00:00                               NaN
# 2018-04-30 00:00:00+00:00                               NaN
# 2018-05-31 00:00:00+00:00                               NaN
# 2018-06-30 00:00:00+00:00                              65.0
# 2018-07-31 00:00:00+00:00                             202.0
# 2018-08-31 00:00:00+00:00                             299.0
# 2018-09-30 00:00:00+00:00                             370.0
# 2018-10-31 00:00:00+00:00                             441.0
# 2018-11-30 00:00:00+00:00                             497.0
# 2018-12-31 00:00:00+00:00                             685.0
# 2019-01-31 00:00:00+00:00                             792.0
# 2019-02-28 00:00:00+00:00                             707.0
# 2019-03-31 00:00:00+00:00                             710.0
# 2019-04-30 00:00:00+00:00                             639.0
# 2019-05-31 00:00:00+00:00                             610.0
# 2019-06-30 00:00:00+00:00                             540.0
# 2019-07-31 00:00:00+00:00                             492.0
#
# course_id                  e9bb9205eeed307ee7cbaa08bfd166c3
# months
# 2016-03-31 00:00:00+00:00                               NaN
# 2016-11-30 00:00:00+00:00                               NaN
# 2017-01-31 00:00:00+00:00                               NaN
# 2017-02-28 00:00:00+00:00                               NaN
# 2017-03-31 00:00:00+00:00                               NaN
# 2017-04-30 00:00:00+00:00                               NaN
# 2017-05-31 00:00:00+00:00                               NaN
# 2017-06-30 00:00:00+00:00                               NaN
# 2017-07-31 00:00:00+00:00                               NaN
# 2017-08-31 00:00:00+00:00                               NaN
# 2017-09-30 00:00:00+00:00                               NaN
# 2017-10-31 00:00:00+00:00                               NaN
# 2017-11-30 00:00:00+00:00                               NaN
# 2017-12-31 00:00:00+00:00                               NaN
# 2018-01-31 00:00:00+00:00                               NaN
# 2018-02-28 00:00:00+00:00                               3.0
# 2018-03-31 00:00:00+00:00                              10.0
# 2018-04-30 00:00:00+00:00                               9.0
# 2018-05-31 00:00:00+00:00                              31.0
# 2018-06-30 00:00:00+00:00                              55.0
# 2018-07-31 00:00:00+00:00                              77.0
# 2018-08-31 00:00:00+00:00                              95.0
# 2018-09-30 00:00:00+00:00                             104.0
# 2018-10-31 00:00:00+00:00                             154.0
# 2018-11-30 00:00:00+00:00                             181.0
# 2018-12-31 00:00:00+00:00                             257.0
# 2019-01-31 00:00:00+00:00                             209.0
# 2019-02-28 00:00:00+00:00                             183.0
# 2019-03-31 00:00:00+00:00                             158.0
# 2019-04-30 00:00:00+00:00                             151.0
# 2019-05-31 00:00:00+00:00                             177.0
# 2019-06-30 00:00:00+00:00                             158.0
# 2019-07-31 00:00:00+00:00                             118.0

# %%
# На основании первого пункта построить line-graph с приростом студентов в каждом месяце для каждого курса.
# 15 графиков. Графики должны иметь заголовки, оси должны быть подписаны. Ticks нужно развернуть так,
# чтобы они были читаемы.

# %%
#y = temp_df.reset_index()['months'].unique().to_numpy()
dates = temp_df.reset_index()['months'].unique().date
course_ids = temp_df.reset_index()['course_id'].unique()
x = range(0,33)
y = temp_df.groupby(['months', 'course_id'])['Unnamed: 0'].count().unstack()

# %%
fig, [[ax0, ax1, ax2], [ax3, ax4, ax5], [ax6, ax7, ax8], [ax9, ax10, ax11], [ax12, ax13, ax14]] \
= plt.subplots(nrows=5, ncols=3, figsize=(20,20))
plt.subplots_adjust(left=None, bottom=None, right=None, top=1.4, wspace=None, hspace=.3)

ax0.plot(dates, y[course_ids[0]])
ax0.set_ylabel('студенты')
ax0.set_title(courses_df[courses_df['id'] == course_ids[0]]['title'].to_list()[0])
ax0.tick_params(labelrotation=45)

ax1.plot(dates, y[course_ids[1]])
ax1.set_title(courses_df[courses_df['id'] == course_ids[1]]['title'].to_list()[0])
ax1.tick_params(labelrotation=45)

ax2.plot(dates, y[course_ids[2]])
ax2.set_title(courses_df[courses_df['id'] == course_ids[2]]['title'].to_list()[0])
ax2.tick_params(labelrotation=45)

ax3.plot(dates, y[course_ids[3]])
ax3.set_ylabel('студенты')
ax3.set_title(courses_df[courses_df['id'] == course_ids[3]]['title'].to_list()[0])
ax3.tick_params(labelrotation=45)

ax4.plot(dates, y[course_ids[4]])
ax4.set_title(courses_df[courses_df['id'] == course_ids[4]]['title'].to_list()[0])
ax4.tick_params(labelrotation=45)

ax5.plot(dates, y[course_ids[5]])
ax5.set_title(courses_df[courses_df['id'] == course_ids[5]]['title'].to_list()[0])
ax5.tick_params(labelrotation=45)

ax6.plot(dates, y[course_ids[6]])
ax6.set_ylabel('студенты')
ax6.set_title(courses_df[courses_df['id'] == course_ids[6]]['title'].to_list()[0])
ax6.tick_params(labelrotation=45)

ax7.plot(dates, y[course_ids[7]])
ax7.set_title(courses_df[courses_df['id'] == course_ids[7]]['title'].to_list()[0])
ax7.tick_params(labelrotation=45)

ax8.plot(dates, y[course_ids[8]])
ax8.set_title(courses_df[courses_df['id'] == course_ids[8]]['title'].to_list()[0])
ax8.tick_params(labelrotation=45)

ax9.plot(dates, y[course_ids[9]])
ax9.set_ylabel('студенты')
ax9.tick_params(labelrotation=45)

ax10.plot(dates, y[course_ids[10]])
ax10.set_title(courses_df[courses_df['id'] == course_ids[10]]['title'].to_list()[0])
ax10.tick_params(labelrotation=45)

ax11.plot(dates, y[course_ids[11]])
ax11.set_title(courses_df[courses_df['id'] == course_ids[11]]['title'].to_list()[0])
ax11.tick_params(labelrotation=45)

ax12.plot(dates, y[course_ids[12]])
ax12.set_ylabel('студенты')
ax12.set_title(courses_df[courses_df['id'] == course_ids[12]]['title'].to_list()[0])
ax12.tick_params(labelrotation=45)

ax13.plot(dates, y[course_ids[13]])
ax13.set_title(courses_df[courses_df['id'] == course_ids[13]]['title'].to_list()[0])
ax13.tick_params(labelrotation=45)

ax14.plot(dates, y[course_ids[14]])
ax14.set_title(courses_df[courses_df['id'] == course_ids[14]]['title'].to_list()[0])
ax14.tick_params(labelrotation=45)
;
# Out:
# ''

# %%
# На основании первого пункта построить line-graph с несколькими линиями, отражающими прирост студентов 
# в каждом месяце для каждого курса. 15 линий на графике. Ticks нужно развернуть так, чтобы они были читаемы.
# График должен иметь заголовок. Ось, отражающая прирост, должна быть подписана. Линия для каждого курса
# должна иметь свой цвет (нужна легенда). Рамок у графика быть не должно

# %%
plt.figure(figsize=(15, 15))
plt.title('Прирост количества студентов по месяцам и курсам')
plt.ylabel('Количество студентов')
plt.box(False)
plt.plot(dates, y[course_ids[0]], label=courses_df[courses_df['id'] == course_ids[0]]['title'].to_list()[0])
plt.plot(dates, y[course_ids[1]], label=courses_df[courses_df['id'] == course_ids[1]]['title'].to_list()[0])
plt.plot(dates, y[course_ids[2]], label=courses_df[courses_df['id'] == course_ids[2]]['title'].to_list()[0])
plt.plot(dates, y[course_ids[3]], label=courses_df[courses_df['id'] == course_ids[3]]['title'].to_list()[0])
plt.plot(dates, y[course_ids[4]], label=courses_df[courses_df['id'] == course_ids[4]]['title'].to_list()[0])
plt.plot(dates, y[course_ids[5]], label=courses_df[courses_df['id'] == course_ids[5]]['title'].to_list()[0])
plt.plot(dates, y[course_ids[6]], label=courses_df[courses_df['id'] == course_ids[6]]['title'].to_list()[0])
plt.plot(dates, y[course_ids[7]], label=courses_df[courses_df['id'] == course_ids[7]]['title'].to_list()[0])
plt.plot(dates, y[course_ids[8]], label=courses_df[courses_df['id'] == course_ids[8]]['title'].to_list()[0])
plt.plot(dates, y[course_ids[9]], label=courses_df[courses_df['id'] == course_ids[9]]['title'].to_list()[0])
plt.plot(dates, y[course_ids[10]], label=courses_df[courses_df['id'] == course_ids[10]]['title'].to_list()[0])
plt.plot(dates, y[course_ids[11]], label=courses_df[courses_df['id'] == course_ids[11]]['title'].to_list()[0])
plt.plot(dates, y[course_ids[12]], label=courses_df[courses_df['id'] == course_ids[12]]['title'].to_list()[0])
plt.plot(dates, y[course_ids[13]], label=courses_df[courses_df['id'] == course_ids[13]]['title'].to_list()[0])
plt.plot(dates, y[course_ids[14]], label=courses_df[courses_df['id'] == course_ids[14]]['title'].to_list()[0])
plt.legend()
plt.show()

# %%
# Рассчитать количество прогрессов по выполнению домашних работ в каждом месяце за всю историю (каждый
# месяц в диапазоне от марта 2016 до июля 2019 включительно) для каждого курса. Учитывать, что выполнение
# домашнего задания может перетекать из одного месяца в другой (такие дз надо включать в общее число
# прогрессов для всех месяцев, которые покрывает срок выполнения этих дз)

# %% [markdown]
# ## 3. Выявление проблемных модулей
#
# 1. **(p)** Рассчитать минимальное, максимальное, среднее, медианное время прохождения каждого модуля (разность между временем начала и окончания выполнения домашней работы) для каждого курса. Если домашних заданий в модуле несколько, то считать разность между временем начала выполнения первой домашней работы и временем окончания выполнения последней домашней работы в модуле
# 2. **(m)** На основании первого пункта построить line-graph с медианным временем прохождения каждого модуля для каждого курса. 15 графиков. Графики должны иметь заголовки
# 3. **(p)**  Чтобы выявить сезонность, посчитать медианное время выполнения домашней работы по месяцам (12 месяцев, январь-декабрь) для каждого курса.
# 4. **(m)** На основании третьего пункта построить line-graph, на который будут нанесены линии для каждого курса с медианным временем выполнения домашней работы по месяцам. 15 линий на графике. График должен иметь заголовок. Ось, отражающая время прохождения, должна быть подписана. Линия для каждого курса должна иметь свой цвет (нужна легенда). Рамок у графика быть не должно  ⭐
# 5. На основании рассчитанных значений сделайте аналитический вывод (должен быть полным и покрывать все полученные выше метрики)

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ## 4. Расчет конверсии
#
# 1. **(p)** Посчитать конверсию перехода студентов из одного модуля в другой на каждом курсе. Формула: отношение количества студентов, приступивших к выполнению домашнего задания в этом модуле (если дз в модуле несколько, то считать по первому дз в модуле), к количеству студентов, сдавших задание в предыдущем модуле (если дз в модуле несколько, то считать по последнему дз в модуле).
# 2. **(m)** Постройте bar-chart, отражающий конверсию перехода студентов из одного модуля в другой на каждом курсе. График должен иметь заголовок. Ticks нужно развернуть так, чтобы они были читаемы
# 3. **(m)** Постройте горизонтальный (столбцы должны располагаться горизонтально) bar-chart, отражающий конверсию перехода студентов из одного модуля в другой на каждом курсе. 15 графиков. Графики должны иметь заголовки. Ticks должны содержать номер и название модуля. Цвет столбцов графиков должен содержать информацию о сфере, к которой относится курс (нужна легенда). Прозрачность должна стоять на отметке 0.1. На графики должна быть нанесена линия медианы конверсии для каждого курса. У медианы должен быть свой цвет. Рамок у графиков быть не должно ⭐
# 4. На основании рассчитанных значений сделайте аналитический вывод (должен быть полным и покрывать все полученные выше метрики)

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ## 5. Метрика успеваемости
#
# &nbsp;&nbsp;&nbsp;&nbsp;*(необязательное задание)*
#
# Иногда студенты берут курсы, которые оказываются для них неподъемными. Это может быть как по причинам недостаточной изначальной подготовки, так и по причинам, связанным с низкой мотивацией студента. Для улучшения качества контента полезно выявить причину. На основании имеющихся данных придумайте метрику успеваемости студента. **Обоснуйте ее.** Выявите таких студентов на каждом курсе, чтобы предоставить продюсерам список проблемных студентов.

# %%
### YOUR CODE HERE ###
